# %%
x=5
print(type(x))
# Out:
# <class 'int'>

# %%
x="Hello World"
print(type(x))
# Out:
# <class 'str'>

# %%
x=20.5
print(type(x))
# Out:
# <class 'float'>

# %%
x=1j
print(type(x))
# Out:
# <class 'complex'>

# %%
x = { "name" : "Aftab" ,"age":25}
print(type(x))
# Out:
# <class 'dict'>

# %%
x=["Banana","Apple","Cherry"]
print(type(x))
# Out:
# <class 'list'>

# %%
x=("Banana","Apple","Cherry")
print(type(x))
# Out:
# <class 'tuple'>

# %%
x={"Banana", "Apple", "Cherry"}
print(type(x))
# Out:
# <class 'set'>

# %%
x=frozenset({"Banana", "Aplle", "Cherry"})
print(type(x))
# Out:
# <class 'frozenset'>

# %%
x=True
print(type(x))
# Out:
# <class 'bool'>

# %%
x=b"Hello"
print(type(x))
# Out:
# <class 'bytes'>

# %%
x=memoryview(bytes(5))
print(type(x))
# Out:
# <class 'memoryview'>

# %%
x=None
print(type(x))
# Out:
# <class 'NoneType'>

# %%
# 
x=str("Hello World")
print(x)
# Out:
# Hello World

# %%
x=int(5)
print(x)
# Out:
# 5

# %%
x=float(20.1)
print(x)
# Out:
# 20.1

# %%
x=complex(1j)
print(x)
# Out:
# 1j

# %%
x=dict({"name":"aftab","Cast":"bhan"})
print(dict)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 x=dic({"name":"aftab","Cast":"bhan"})
#       2 print(dic)
#
# NameError: name 'dic' is not defined
