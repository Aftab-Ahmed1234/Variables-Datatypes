# %%
x=5
print(type(x))
# Out:
# <class 'int'>

# %%
x="Hello World"
print(type(x))
# Out:
# <class 'str'>

# %%
x=20.5
print(type(x))
# Out:
# <class 'float'>

# %%
x=1j
print(type(x))
# Out:
# <class 'complex'>

# %%
x = { "name" : "Aftab" ,"age":25}
print(type(x))
# Out:
# <class 'dict'>

# %%
x=["Banana","Apple","Cherry"]
print(type(x))
# Out:
# <class 'list'>

# %%
x=("Banana","Apple","Cherry")
print(type(x))
# Out:
# <class 'tuple'>

# %%
x={"Banana", "Apple", "Cherry"}
print(type(x))
# Out:
# <class 'set'>

# %%
x=frozenset({"Banana", "Aplle", "Cherry"})
print(type(x))
# Out:
# <class 'frozenset'>

# %%
x=True
print(type(x))
# Out:
# <class 'bool'>

# %%
x=b"Hello"
print(type(x))
# Out:
# <class 'bytes'>

# %%
x=memoryview(bytes(5))
print(type(x))
# Out:
# <class 'memoryview'>

# %%
x=None
print(type(x))
# Out:
# <class 'NoneType'>

# %%
# 
x=str("Hello World")
print(x)
# Out:
# Hello World

# %%
x=int(5)
print(x)
# Out:
# 5

# %%
x=float(20.1)
print(x)
# Out:
# 20.1

# %%
x=complex(1j)
print(x)
# Out:
# 1j

# %%
x=dict({"name":"aftab","Cast":"bhan"})
print(x)
# Out:
# <class 'dict'>

# %%
x=list(["banana","Apple","Mango"])
print(x)
# Out:
# ['banana', 'Apple', 'Mango']

# %%
x=tuple(("Apple","Banana","Mango"))
print(x)
# Out:
# ('Apple', 'Banana', 'Mango')

# %%
x=set({"Apple","Banana","Mango"})
print(x)
# Out:
# {'Mango', 'Banana', 'Apple'}

# %%
x=frozenset(({"Apple","Banana","Mango"}))
print(x)
# Out:
# frozenset({'Mango', 'Banana', 'Apple'})

# %%
x=bool(True)
print(x)
# Out:
# True

# %%
x=bytes(b"Hello")
print(x)
# Out:
# b'Hello'

# %%
x=memoryview(bytes(4))
print(x)

# %%
x=None
print(x)
# Out:
# None
